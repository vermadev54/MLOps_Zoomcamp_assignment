# %% [markdown]
# ### NOTE: All code modification has been done in homework.py

# %% [markdown]
# ## Question 1: The output of which task needs .result()

# %%
#solution before adding .result() and logging 

# lr, dv = train_model(df_train_processed, categorical).result()

# %%
# !python3 homework.py
# Out:
# 05:43:36.948 | INFO    | prefect.engine - Created flow run 'hopeful-ocelot' for flow 'main'
# 05:43:36.949 | INFO    | Flow run 'hopeful-ocelot' - Using task runner 'SequentialTaskRunner'
# 05:43:37.035 | INFO    | Flow run 'hopeful-ocelot' - Created task run 'read_data-4c7f9de4-0' for task 'read_data'
# 05:43:43.958 | INFO    | Task run 'read_data-4c7f9de4-0' - Finished in state Completed()
# 05:43:44.190 | INFO    | Flow run 'hopeful-ocelot' - Created task run 'prepare_features-4ee39d9f-0' for task 'prepare_features'
# The mean duration of training is 16.2472533682457
# 05:43:44.405 | INFO    | Task run 'prepare_features-4ee39d9f-0' - The mean duration of training is 16.2472533682457
# 05:43:51.306 | INFO    | Task run 'prepare_features-4ee39d9f-0' - Finished in state Completed()
# 05:43:51.347 | INFO    | Flow run 'hopeful-ocelot' - Created task run 'read_data-4c7f9de4-1' for task 'read_data'
# ...

# %% [markdown]
# ## Question 2: Validation RMSE.
#
# Solution: The MSE of validation is: 11.637031861052277

# %%
# !python3 homework.py
# Out:
# 09:25:01.243 | INFO    | prefect.engine - Created flow run 'calm-dragonfly' for flow 'main'
# 09:25:01.243 | INFO    | Flow run 'calm-dragonfly' - Using task runner 'SequentialTaskRunner'
# 09:25:01.328 | INFO    | Flow run 'calm-dragonfly' - Created task run 'get_paths-6e696e34-0' for task 'get_paths'
# 09:25:01.394 | INFO    | Task run 'get_paths-6e696e34-0' - Finished in state Completed()
# 09:25:01.425 | INFO    | Flow run 'calm-dragonfly' - Created task run 'read_data-4c7f9de4-0' for task 'read_data'
# 09:25:09.438 | INFO    | Task run 'read_data-4c7f9de4-0' - Finished in state Completed()
# 09:25:09.482 | INFO    | Flow run 'calm-dragonfly' - Created task run 'prepare_features-4ee39d9f-0' for task 'prepare_features'
# The mean duration of training is 18.230538791569113
# 09:25:09.728 | INFO    | Task run 'prepare_features-4ee39d9f-0' - The mean duration of training is 18.230538791569113
# ...

# %% [markdown]
# ## Question 3: Size of DictVectorizer.
# Solution:13000 bytes

# %%
ls -ltr models/
# Out:
# total 348
# -rw-rw-r-- 1 ubuntu ubuntu 305256 Jun  8 06:36 preprocessor.b
# -rw-rw-r-- 1 ubuntu ubuntu   4581 Jun  9 09:24 model-2021-03-15.bin
# -rw-rw-r-- 1 ubuntu ubuntu  13191 Jun  9 09:24 dv-2021-03-15.b
# -rw-rw-r-- 1 ubuntu ubuntu   4581 Jun  9 09:25 model-2021-08-15.bin
# -rw-rw-r-- 1 ubuntu ubuntu  13191 Jun  9 09:25 dv-2021-08-15.b

# %% [markdown]
# ## Question 4: CronSchedule.
# Solution: cron="0 9 15 * *"

# %% [markdown]
# ![Screenshot%202022-06-09%20at%202.39.33%20PM.png](attachment:Screenshot%202022-06-09%20at%202.39.33%20PM.png)

# %% [markdown]
# ## Question 5: How many flow runs are scheduled in advance?
#
# Solution: 3

# %%
# !prefect deployment create homework.py
# Out:
# Loading deployment specifications from python script at 'homework.py'...
# /home/ubuntu/Week3_mlops-zoomcamp/Week3_env/lib/python3.9/site-packages/prefect/deployments.py:247: UserWarning: You have configured local storage, this deployment will only be usable from the current machine..
#   warnings.warn(
# Creating deployment 'model_training_2021-08-15' for flow 'main'...
# Deploying flow script from
# '/home/ubuntu/Week3_mlops-zoomcamp/Week3_notebook/homework.py' using Local
# Storage...
# Created deployment 'main/model_training_2021-08-15'.
# View your new deployment with:
#
#     prefect deployment inspect 'main/model_training_2021-08-15'
# Created 1 deployments!

# %% [markdown]
# ![Screenshot%202022-06-09%20at%203.18.00%20PM.png](attachment:Screenshot%202022-06-09%20at%203.18.00%20PM.png)

# %% [markdown]
# ## Question 6: Creating the work queue.
# Solution: prefect work-queue preview

# %%
# !prefect work-queue preview 6d29ee07-9bc6-43d9-b798-49cf3dd91cb6 --hours 90000
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Scheduled St… ┃ Run ID                  ┃ Name     ┃ Deployment ID           ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2022-09-15 1… │ 346a644d-d070-4135-83a… │ sophist… │ aa61761a-1827-43ac-b8c… │
# │ 2022-08-15 1… │ fefbb541-040d-4966-87f… │ mauve-s… │ aa61761a-1827-43ac-b8c… │
# │ 2022-07-15 1… │ 1d62bf69-bff9-47c8-b0f… │ cyan-to… │ aa61761a-1827-43ac-b8c… │
# │ 2022-06-15 1… │ a5977d2b-8461-490a-be8… │ faithfu… │ aa61761a-1827-43ac-b8c… │
# └───────────────┴─────────────────────────┴──────────┴─────────────────────────┘
#                             (**) denotes a late run
