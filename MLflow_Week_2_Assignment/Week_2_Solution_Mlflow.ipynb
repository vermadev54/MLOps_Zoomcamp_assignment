# %% [markdown]
# #### Q1:  Solution

# %%
# !mlflow --version
# Out:
# mlflow, version 1.26.1

# %%
# !mkdir output
# Out:
# mkdir: output: File exists

# %%
ls
# Out:
# Untitled.ipynb              output/
# data/                       preprocess_data.py
# hpo.py                      register_model.py
# hpo_modified.py             train.py
# mlflow.db                   train_with_auto_logging.py
# mlruns/

# %%
# !python preprocess_data.py --raw_data_path data/ --dest_path ./output

# %% [markdown]
# ### Q2:  solution : 4 files

# %%
ls output/
# Out:
# dv.pkl     test.pkl   train.pkl  valid.pkl

# %% [markdown]
# ### Q3 Solution: file train.py changed to train_with_auto_logging.py

# %%
# !python train_with_auto_logging.py --data_path ./output
# Out:
# 2022/05/30 13:08:58 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-homework_week_2' does not exist. Creating a new experiment.

# %% [markdown]
# ![Screenshot%202022-05-30%20at%201.32.59%20PM.png](attachment:Screenshot%202022-05-30%20at%201.32.59%20PM.png)

# %% [markdown]
# ### Q4 Solution : mlflow ui --backend-store-uri sqlite:///mlflow.db --default-artifact-root artifacts

# %% [markdown]
# ### Q5 solution: file hpo.py changed to hpo_modified.py

# %%
# !python hpo_modified.py --data_path ./output
# Out:
# 2022/05/30 13:14:26 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
# 100%|█████████| 50/50 [05:20<00:00,  6.40s/trial, best loss: 6.6284257482044735]

# %% [markdown]
# ![Screenshot%202022-05-30%20at%201.45.07%20PM.png](attachment:Screenshot%202022-05-30%20at%201.45.07%20PM.png)

# %% [markdown]
# ### Q6 solution

# %%
# !python register_model.py --data_path ./output --top_n 15
# Out:
# 2022/05/30 13:22:02 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# run id: f0ed3665d6ca4472a12ffd99398e8845, test_rmse: 6.5479
# run id: bfcf7e9c604b4968ba962ed5c4076767, test_rmse: 6.5489
# run id: 944f9fc1c1ef4863b72edd2f3eddf6aa, test_rmse: 6.5491
# run id: 6d6d8c4174944741b8d5560cb996b6d9, test_rmse: 6.5491
# run id: 930f479cb9c448c8a32b8b0c70e05945, test_rmse: 6.5498
# run id: 9d9eb96047774987b72f30387cf9e7f8, test_rmse: 6.5508
# run id: 698d1474496c4d14b23459b171fe92ef, test_rmse: 6.5516
# run id: 3ebc7815acab4a7eb1dd84776f9ca21f, test_rmse: 6.5523
# run id: 0ad28362724240b18777ca3655928985, test_rmse: 6.5529
# run id: d20cfaaf408549c1a847960bec832dcd, test_rmse: 6.5577
# run id: cdb35a262d05432a914af54a9bbf5ea9, test_rmse: 6.5589
# run id: 5d106b5fdd294f72942769b6d45efc94, test_rmse: 6.5632
# run id: 15650c71be9449cd9ba1422430931c22, test_rmse: 6.5654
# ...

# %% [markdown]
# ![Screenshot%202022-05-30%20at%201.52.09%20PM.png](attachment:Screenshot%202022-05-30%20at%201.52.09%20PM.png)

# %% [markdown]
# ![Screenshot%202022-05-30%20at%201.53.19%20PM.png](attachment:Screenshot%202022-05-30%20at%201.53.19%20PM.png)
